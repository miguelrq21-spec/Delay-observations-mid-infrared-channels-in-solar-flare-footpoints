# %%
# !pip install sunpy[all]
# !pip install radyn-xtools
# Out:
# Collecting sunpy[all]
#   Downloading sunpy-7.0.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: astropy>=6.1.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from sunpy[all]) (7.0.1)
# Requirement already satisfied: numpy>=1.25.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from sunpy[all]) (2.0.2)
# Requirement already satisfied: packaging>=23.2 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from sunpy[all]) (24.2)
# Collecting parfive>=2.1.0 (from parfive[ftp]>=2.1.0->sunpy[all])
#   Using cached parfive-2.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from sunpy[all]) (2.0.1.5)
# Requirement already satisfied: requests>=2.32.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from sunpy[all]) (2.32.3)
# Collecting fsspec>=2023.6.0 (from sunpy[all])
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: astropy-iers-data>=0.2025.1.31.12.41.4 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from astropy>=6.1.0->sunpy[all]) (0.2025.4.21.0.37.6)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from astropy>=6.1.0->sunpy[all]) (6.0.2)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (4.67.1)
# Requirement already satisfied: aiohttp in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (3.11.10)
# Collecting aioftp>=0.17.1 (from parfive[ftp]>=2.1.0->sunpy[all])
#   Downloading aioftp-0.27.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from requests>=2.32.0->sunpy[all]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from requests>=2.32.0->sunpy[all]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from requests>=2.32.0->sunpy[all]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from requests>=2.32.0->sunpy[all]) (2025.4.26)
# Requirement already satisfied: asdf-astropy>=0.5.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from sunpy[all]) (0.7.1)
# Requirement already satisfied: asdf>=3.0.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from sunpy[all]) (4.1.0)
# Collecting glymur>=0.13.0 (from sunpy[all])
#   Downloading glymur-0.14.4-py3-none-any.whl.metadata (1.3 kB)
# Collecting lxml!=5.0.0,>=4.9.1 (from sunpy[all])
#   Downloading lxml-6.0.2-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Collecting opencv-python>=4.8.0.74 (from sunpy[all])
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: scikit-image>=0.21.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from sunpy[all]) (0.25.2)
# Collecting spiceypy>=6.0.0 (from sunpy[all])
#   Downloading spiceypy-7.0.0-cp312-cp312-win_amd64.whl.metadata (7.3 kB)
# Requirement already satisfied: asdf-standard>=1.1.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from asdf>=3.0.0->sunpy[all]) (1.1.1)
# Requirement already satisfied: asdf-transform-schemas>=0.3 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from asdf>=3.0.0->sunpy[all]) (0.5.0)
# Requirement already satisfied: jmespath>=0.6.2 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from asdf>=3.0.0->sunpy[all]) (1.0.1)
# Requirement already satisfied: semantic_version>=2.8 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from asdf>=3.0.0->sunpy[all]) (2.10.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from asdf>=3.0.0->sunpy[all]) (24.3.0)
# Requirement already satisfied: asdf-coordinates-schemas>=0.3 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from asdf-astropy>=0.5.0->sunpy[all]) (0.3.0)
# Requirement already satisfied: pillow in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from glymur>=0.13.0->sunpy[all]) (11.2.1)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from scikit-image>=0.21.0->sunpy[all]) (1.15.2)
# Requirement already satisfied: networkx>=3.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from scikit-image>=0.21.0->sunpy[all]) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from scikit-image>=0.21.0->sunpy[all]) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from scikit-image>=0.21.0->sunpy[all]) (2025.3.30)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from scikit-image>=0.21.0->sunpy[all]) (0.4)
# Requirement already satisfied: colorama in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from tqdm>=4.27.0->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (0.4.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy[all]) (1.18.0)
# Requirement already satisfied: contourpy>=1.1.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from sunpy[all]) (1.3.2)
# Requirement already satisfied: matplotlib>=3.8.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from sunpy[all]) (3.10.1)
# Collecting mpl-animators>=1.2.0 (from sunpy[all])
#   Using cached mpl_animators-1.2.4-py3-none-any.whl.metadata (6.4 kB)
# Collecting reproject>=0.12.0 (from sunpy[all])
#   Downloading reproject-0.17.0-cp311-abi3-win_amd64.whl.metadata (3.4 kB)
# Collecting beautifulsoup4>=4.13.0 (from sunpy[all])
#   Downloading beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting drms>=0.7.1 (from sunpy[all])
#   Using cached drms-0.9.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.9.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from sunpy[all]) (2.9.0.post0)
# Collecting zeep>=4.3.0 (from sunpy[all])
#   Downloading zeep-4.3.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: cdflib>=1.3.2 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from sunpy[all]) (1.3.4)
# Collecting h5netcdf>=1.2.0 (from sunpy[all])
#   Using cached h5netcdf-1.6.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: h5py>=3.9.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from sunpy[all]) (3.13.0)
# Requirement already satisfied: pandas>=2.1.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from sunpy[all]) (2.2.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from beautifulsoup4>=4.13.0->sunpy[all]) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from beautifulsoup4>=4.13.0->sunpy[all]) (4.12.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from matplotlib>=3.8.0->sunpy[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from matplotlib>=3.8.0->sunpy[all]) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from matplotlib>=3.8.0->sunpy[all]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from matplotlib>=3.8.0->sunpy[all]) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from pandas>=2.1.0->sunpy[all]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from pandas>=2.1.0->sunpy[all]) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from python-dateutil>=2.9.0->sunpy[all]) (1.17.0)
# Collecting astropy-healpix>=1.0 (from reproject>=0.12.0->sunpy[all])
#   Using cached astropy_healpix-1.1.2-cp310-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting dask>=2021.8 (from dask[array]>=2021.8->reproject>=0.12.0->sunpy[all])
#   Downloading dask-2025.9.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting zarr>=2.11.0 (from reproject>=0.12.0->sunpy[all])
#   Downloading zarr-3.1.3-py3-none-any.whl.metadata (10 kB)
# Collecting pyavm>=0.9.6 (from reproject>=0.12.0->sunpy[all])
#   Using cached PyAVM-0.9.6-py3-none-any.whl.metadata (5.6 kB)
# Collecting isodate>=0.5.4 (from zeep>=4.3.0->sunpy[all])
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: platformdirs>=1.4.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from zeep>=4.3.0->sunpy[all]) (4.3.7)
# Collecting requests-toolbelt>=0.7.1 (from zeep>=4.3.0->sunpy[all])
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests-file>=1.5.1 (from zeep>=4.3.0->sunpy[all])
#   Using cached requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: click>=8.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from dask>=2021.8->dask[array]>=2021.8->reproject>=0.12.0->sunpy[all]) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from dask>=2021.8->dask[array]>=2021.8->reproject>=0.12.0->sunpy[all]) (3.0.0)
# Collecting partd>=1.4.0 (from dask>=2021.8->dask[array]>=2021.8->reproject>=0.12.0->sunpy[all])
#   Using cached partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting toolz>=0.10.0 (from dask>=2021.8->dask[array]>=2021.8->reproject>=0.12.0->sunpy[all])
#   Using cached toolz-1.0.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting donfig>=0.8 (from zarr>=2.11.0->reproject>=0.12.0->sunpy[all])
#   Using cached donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting numcodecs>=0.14 (from numcodecs[crc32c]>=0.14->zarr>=2.11.0->reproject>=0.12.0->sunpy[all])
#   Downloading numcodecs-0.16.3-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting crc32c>=2.7 (from numcodecs[crc32c]>=0.14->zarr>=2.11.0->reproject>=0.12.0->sunpy[all])
#   Using cached crc32c-2.7.1-cp312-cp312-win_amd64.whl.metadata (7.5 kB)
# Collecting locket (from partd>=1.4.0->dask>=2021.8->dask[array]>=2021.8->reproject>=0.12.0->sunpy[all])
#   Using cached locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Using cached parfive-2.2.0-py3-none-any.whl (34 kB)
# Downloading sunpy-7.0.2-py3-none-any.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.5 MB ? eta -:--:--
#    --------- ------------------------------ 0.8/3.5 MB 2.0 MB/s eta 0:00:02
#    --------------- ------------------------ 1.3/3.5 MB 2.4 MB/s eta 0:00:01
#    --------------------------- ------------ 2.4/3.5 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 3.7 MB/s eta 0:00:00
# Downloading aioftp-0.27.2-py3-none-any.whl (44 kB)
# Downloading glymur-0.14.4-py3-none-any.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------- ----------------- 1.6/2.7 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 7.9 MB/s eta 0:00:00
# Downloading lxml-6.0.2-cp312-cp312-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    --------------- ------------------------ 1.6/4.0 MB 8.4 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 8.9 MB/s eta 0:00:00
# Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
# Downloading spiceypy-7.0.0-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------------------------- -------- 1.6/2.0 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 5.9 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Using cached drms-0.9.0-py3-none-any.whl (37 kB)
# Using cached h5netcdf-1.6.4-py3-none-any.whl (50 kB)
# Using cached mpl_animators-1.2.4-py3-none-any.whl (35 kB)
# Downloading reproject-0.17.0-cp311-abi3-win_amd64.whl (994 kB)
#    ---------------------------------------- 0.0/994.0 kB ? eta -:--:--
#    ---------------------------------------- 994.0/994.0 kB 9.4 MB/s eta 0:00:00
# Downloading zeep-4.3.2-py3-none-any.whl (101 kB)
# Using cached astropy_healpix-1.1.2-cp310-abi3-win_amd64.whl (54 kB)
# Downloading dask-2025.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 8.6 MB/s eta 0:00:00
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# Using cached PyAVM-0.9.6-py3-none-any.whl (378 kB)
# Using cached requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading zarr-3.1.3-py3-none-any.whl (276 kB)
# Using cached donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.3-cp312-cp312-win_amd64.whl (806 kB)
#    ---------------------------------------- 0.0/806.3 kB ? eta -:--:--
#    ---------------------------------------- 806.3/806.3 kB 7.0 MB/s eta 0:00:00
# Using cached partd-1.4.2-py3-none-any.whl (18 kB)
# Using cached toolz-1.0.0-py3-none-any.whl (56 kB)
# Using cached crc32c-2.7.1-cp312-cp312-win_amd64.whl (39 kB)
# Using cached locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: toolz, spiceypy, pyavm, opencv-python, numcodecs, lxml, locket, isodate, fsspec, donfig, crc32c, beautifulsoup4, aioftp, requests-toolbelt, requests-file, partd, h5netcdf, glymur, zeep, zarr, parfive, mpl-animators, drms, dask, astropy-healpix, sunpy, reproject
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.3
#     Uninstalling beautifulsoup4-4.12.3:
#       Successfully uninstalled beautifulsoup4-4.12.3
# Successfully installed aioftp-0.27.2 astropy-healpix-1.1.2 beautifulsoup4-4.14.2 crc32c-2.7.1 dask-2025.9.1 donfig-0.8.1.post1 drms-0.9.0 fsspec-2025.9.0 glymur-0.14.4 h5netcdf-1.6.4 isodate-0.7.2 locket-1.0.0 lxml-6.0.2 mpl-animators-1.2.4 numcodecs-0.16.3 opencv-python-4.12.0.88 parfive-2.2.0 partd-1.4.2 pyavm-0.9.6 reproject-0.17.0 requests-file-2.1.0 requests-toolbelt-1.0.0 spiceypy-7.0.0 sunpy-7.0.2 toolz-1.0.0 zarr-3.1.3 zeep-4.3.2
# Collecting radyn-xtools
#   Downloading radyn_xtools-1.9.5.tar.gz (4.4 MB)
#      ---------------------------------------- 0.0/4.4 MB ? eta -:--:--
#      --------- ------------------------------ 1.0/4.4 MB 8.4 MB/s eta 0:00:01
#      -------------------------- ------------- 2.9/4.4 MB 8.8 MB/s eta 0:00:01
#      ---------------------------------------- 4.4/4.4 MB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: notebook in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from radyn-xtools) (7.3.2)
# Requirement already satisfied: cdflib>=0.4.9 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from radyn-xtools) (1.3.4)
# Requirement already satisfied: numpy>=1.25.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from radyn-xtools) (2.0.2)
# Collecting plotly>=5.15.0 (from radyn-xtools)
#   Downloading plotly-6.3.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting ipympl>=0.9.3 (from radyn-xtools)
#   Downloading ipympl-0.9.8-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: pandas>=2.0.3 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from radyn-xtools) (2.2.3)
# Requirement already satisfied: astropy>=5.3.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from radyn-xtools) (7.0.1)
# Requirement already satisfied: scipy>=1.11.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from radyn-xtools) (1.15.2)
# Requirement already satisfied: matplotlib>=3.7.2 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from radyn-xtools) (3.10.1)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from astropy>=5.3.1->radyn-xtools) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.1.31.12.41.4 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from astropy>=5.3.1->radyn-xtools) (0.2025.4.21.0.37.6)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from astropy>=5.3.1->radyn-xtools) (6.0.2)
# Requirement already satisfied: packaging>=22.0.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from astropy>=5.3.1->radyn-xtools) (24.2)
# Requirement already satisfied: ipython<10 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from ipympl>=0.9.3->radyn-xtools) (8.30.0)
# Collecting ipywidgets<9,>=7.6.0 (from ipympl>=0.9.3->radyn-xtools)
#   Downloading ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pillow in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from ipympl>=0.9.3->radyn-xtools) (11.2.1)
# Requirement already satisfied: traitlets<6 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from ipympl>=0.9.3->radyn-xtools) (5.14.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from matplotlib>=3.7.2->radyn-xtools) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from matplotlib>=3.7.2->radyn-xtools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from matplotlib>=3.7.2->radyn-xtools) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from matplotlib>=3.7.2->radyn-xtools) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from matplotlib>=3.7.2->radyn-xtools) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from matplotlib>=3.7.2->radyn-xtools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from pandas>=2.0.3->radyn-xtools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from pandas>=2.0.3->radyn-xtools) (2025.2)
# Collecting narwhals>=1.15.1 (from plotly>=5.15.0->radyn-xtools)
#   Downloading narwhals-2.7.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from notebook->radyn-xtools) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from notebook->radyn-xtools) (2.27.3)
# Requirement already satisfied: jupyterlab<4.4,>=4.3.4 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from notebook->radyn-xtools) (4.3.4)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from notebook->radyn-xtools) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from notebook->radyn-xtools) (6.4.2)
# Requirement already satisfied: decorator in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from ipython<10->ipympl>=0.9.3->radyn-xtools) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from ipython<10->ipympl>=0.9.3->radyn-xtools) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from ipython<10->ipympl>=0.9.3->radyn-xtools) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from ipython<10->ipympl>=0.9.3->radyn-xtools) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from ipython<10->ipympl>=0.9.3->radyn-xtools) (2.19.1)
# Requirement already satisfied: stack-data in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from ipython<10->ipympl>=0.9.3->radyn-xtools) (0.2.0)
# Requirement already satisfied: colorama in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from ipython<10->ipympl>=0.9.3->radyn-xtools) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl>=0.9.3->radyn-xtools) (0.2.1)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets<9,>=7.6.0->ipympl>=0.9.3->radyn-xtools)
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets<9,>=7.6.0->ipympl>=0.9.3->radyn-xtools)
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (4.7.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (2.0.15)
# Requirement already satisfied: pyzmq>=24 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook->radyn-xtools) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook->radyn-xtools) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook->radyn-xtools) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook->radyn-xtools) (2.2.0)
# Requirement already satisfied: setuptools>=40.8.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook->radyn-xtools) (75.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->radyn-xtools) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->radyn-xtools) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->radyn-xtools) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->radyn-xtools) (2.32.3)
# Requirement already satisfied: six>=1.5 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.7.2->radyn-xtools) (1.17.0)
# Requirement already satisfied: idna>=2.8 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (1.3.0)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (4.12.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (21.2.0)
# Requirement already satisfied: certifi in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook->radyn-xtools) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook->radyn-xtools) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook->radyn-xtools) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook->radyn-xtools) (1.8.11)
# Requirement already satisfied: nest-asyncio in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook->radyn-xtools) (1.6.0)
# Requirement already satisfied: psutil in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook->radyn-xtools) (5.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jedi>=0.16->ipython<10->ipympl>=0.9.3->radyn-xtools) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->radyn-xtools) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->radyn-xtools) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->radyn-xtools) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->radyn-xtools) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (308)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (3.2.1)
# Requirement already satisfied: rfc3339-validator in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (1.5.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (2.20.0)
# Requirement already satisfied: wcwidth in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<10->ipympl>=0.9.3->radyn-xtools) (0.2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->radyn-xtools) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->radyn-xtools) (2.3.0)
# Requirement already satisfied: executing in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from stack-data->ipython<10->ipympl>=0.9.3->radyn-xtools) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from stack-data->ipython<10->ipympl>=0.9.3->radyn-xtools) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from stack-data->ipython<10->ipympl>=0.9.3->radyn-xtools) (0.2.2)
# Requirement already satisfied: webencodings in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (1.4.0)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->radyn-xtools)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->radyn-xtools)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->radyn-xtools)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->radyn-xtools)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->radyn-xtools)
#   Using cached webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (2.5)
# Requirement already satisfied: pycparser in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\migue\anaconda3\envs\radyn\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->radyn-xtools) (1.3.0)
# Downloading ipympl-0.9.8-py3-none-any.whl (515 kB)
# Downloading plotly-6.3.1-py3-none-any.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.8 MB 4.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.8 MB 5.4 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.8 MB 6.5 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.8 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 7.4 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Downloading narwhals-2.7.0-py3-none-any.whl (412 kB)
# Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------------------- -------------------- 1.0/2.2 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 5.4 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached webcolors-24.11.1-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Building wheels for collected packages: radyn-xtools
#   Building wheel for radyn-xtools (setup.py): started
#   Building wheel for radyn-xtools (setup.py): finished with status 'done'
#   Created wheel for radyn-xtools: filename=radyn_xtools-1.9.5-py3-none-any.whl size=4397384 sha256=15ec0442f54d20b7d80e0f6adab51a30a7405464d097124916d34c2930f386f9
#   Stored in directory: c:\users\migue\appdata\local\pip\cache\wheels\ff\8a\c7\4887ae3cabb01fac7acfd94c493f0d222fe3d6f5f0268c3010
# Successfully built radyn-xtools
# Installing collected packages: widgetsnbextension, webcolors, uri-template, narwhals, jupyterlab_widgets, jsonpointer, fqdn, plotly, isoduration, ipywidgets, ipympl, radyn-xtools
# Successfully installed fqdn-1.5.1 ipympl-0.9.8 ipywidgets-8.1.7 isoduration-20.11.0 jsonpointer-3.0.0 jupyterlab_widgets-3.0.15 narwhals-2.7.0 plotly-6.3.1 radyn-xtools-1.9.5 uri-template-1.3.0 webcolors-24.11.1 widgetsnbextension-4.0.14

# %%
import os
from os.path import dirname, join as pjoin
import scipy.io as sio
from scipy.io import readsav
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.patches as patches
from matplotlib.patches import Rectangle
import matplotlib.gridspec as gridspec
import matplotlib.animation as animation
from matplotlib.animation import FuncAnimation
import glob

import astropy.units as u
from astropy.coordinates import SkyCoord
from astropy.visualization import time_support
from astropy.io import fits

from datetime import datetime, timedelta

import sunpy.map
from sunpy import timeseries as ts
from sunpy.net import Fido
from sunpy.net import attrs as a
from sunpy.coordinates import frames


# %matplotlib inline
from scipy import signal
from scipy import stats


from scipy.optimize import curve_fit

import pickle
import math
import scipy.constants as const

from typing import List

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
folder = "/content"
folder= "/content/drive/Othercomputers/UofG_Computer/IR/Delay-observations-mid-infrared-channels-in-solar-flare-footpoints"
folder=r"C:\Users\migue\OneDrive - University of Glasgow\IR\Delay-observations-mid-infrared-channels-in-solar-flare-footpoints"

# %%
# Colourblind-friendly palette from colour universal design (CUD)
CB = ['#377eb8', '#ff7f00', '#4daf4a',
                  '#f781bf', '#a65628', '#984ea3',
                  '#999999', '#e41a1c', '#dede00']


# https://jfly.uni-koeln.de/color/
named_colors = {"black": "#000000",
    "orange": "#e69f00",
    "skyblue": "#56b4e9",
    "bluish green": "#009e73",
    "yellow": "#f0e442",
    "blue": "#0072b2",
    "vermilion": "#d55e00",
    "reddish purple": "#cc79a7",
}
cud_palette = list(named_colors.values())


def cud(n: int = len(cud_palette), start: int = 0) -> List[str]:
    remainder = cud_palette[:start]
    palette = cud_palette[start:] + remainder
    return palette[:n]


palette = cud()

# %%
df_10 = pd.read_csv(f"{folder}/intensity_data_10um.csv", parse_dates=['time_10'])
df_05 = pd.read_csv(f"{folder}/intensity_data_05um.csv", parse_dates=['time_05'])

sp_I_10 = df_10['sp_I_10'].values
fA_I_10 = df_10['fA_I_10'].values
fB_I_10 = df_10['fB_I_10'].values
qs_I_10 = df_10['qs_I_10'].values
time_10 = df_10['time_10']

sp_I_05 = df_05['sp_I_05'].values
fA_I_05 = df_05['fA_I_05'].values
fB_I_05 = df_05['fB_I_05'].values
qs_I_05 = df_05['qs_I_05'].values
time_05 = df_05['time_05']

# %%
plt.figure(figsize=(10, 5))
plt.xlabel('Time HH:MM:SS',fontsize=12)
plt.ylabel('Average Intensity ROI',fontsize=12)

plt.plot(time_05, fA_I_05, color=palette[4], label='flare A 5.2um')
plt.plot(time_05, fB_I_05, color=palette[5], label='flare B 5.2um')
plt.plot(time_05, qs_I_05, color=palette[0], label='quiet sun 5.2um')
plt.plot(time_05, sp_I_05, color=palette[1], label='Sunspot penumbra 5.2um')


plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
plt.gca().xaxis.set_major_locator(mdates.MinuteLocator(interval=2))
plt.xticks(rotation=0)
plt.grid(True)
plt.legend(fontsize=12)#,loc='lower right')
plt.tight_layout()

plt.show()

# %%
y=np.arange(0, len(time_10), 1)*((1.067-1.05)/len(time_10))+1.05 #Linear estimate of the  gradual increase in intensity.

plt.figure(figsize=(10, 5))
plt.xlabel('Time HH:MM:SS',fontsize=12)
plt.ylabel('Average Intensity ROI',fontsize=12)

plt.plot(time_10, fA_I_10, color=palette[2], label='flare A 8.2 µm')
plt.plot(time_10, fB_I_10, color=palette[3], label='flare B 8.2 µm')
plt.plot(time_10, qs_I_10, color=palette[0], label='quiet sun 8.2 µm')
plt.plot(time_10, sp_I_10, color=palette[1], label='Sunspot penumbra 8.2 µm')

plt.plot(time_10, y, 'grey')
plt.annotate('gradual increase', xy=(datetime(2014,9,24,17,52,00), 1.053), xytext=(datetime(2014,9,24,17,52,30), 1.03), arrowprops=dict(facecolor='k', width=0.8), size=10)
plt.gca().add_patch(Rectangle((datetime(2014,9,24,17,55,30), 1), datetime(2014,9,24,17,52,30)-datetime(2014,9,24,17,52,00),0.1, edgecolor = 'grey', facecolor = 'blue', fill=False, lw=3))
plt.annotate('small peaks', xy=(datetime(2014,9,24,17,56,00), 1.03), xytext=(datetime(2014,9,24,17,57,0), 1.029), arrowprops=dict(facecolor='k', width=0.8), size=10)

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
plt.gca().xaxis.set_major_locator(mdates.MinuteLocator(interval=2))
plt.xticks(rotation=0)
plt.grid(True)
plt.legend(fontsize=12,loc='upper right')
plt.tight_layout()


# Guardar imágenes
#plt.savefig(f"{folder}/img_paper_1/curva_intensidad.eps", format="eps", dpi=300)
#plt.savefig(r"C:\Users\migue\OneDrive - University of Glasgow\IR\img_paper_1\curva_intensidad.eps", format="eps", dpi=300)
#plt.savefig(r"C:\Users\migue\OneDrive - University of Glasgow\IR\img_paper_1\curva_intensidad.png", format="png", dpi=300)

plt.show()

# %% [markdown]
# GOES data

# %%
file_goes15 = f"{folder}/goes_data.nc"
goes_15 = ts.TimeSeries(file_goes15)

# %%
from datetime import datetime

df = goes_15.to_dataframe()
goes_15 = ts.TimeSeries(df, goes_15.meta, goes_15.units)

goes_flare = goes_15.truncate("2014-09-24 17:44", "2014-09-24 18:01")
time_support()

fig, ax = plt.subplots(figsize=(10, 5))
ax.set_title("2014-09-24 - GOES X-ray fluxes GOES C 7.0 class flare")

ax.plot(goes_flare.time.datetime, goes_flare.quantity("xrsb"), label = "1.0 - 8.0  Å", color="C1")
ax.plot(goes_flare.time.datetime, goes_flare.quantity("xrsa"), label ="0.5 - 4.0  Å", color="C0")

ax.set_ylabel("Wm$^{-2}$")

# Líneas verticales
# Convertir cada Time a datetime compatible con matplotlib
from astropy.time import Time

start = Time('2014-09-24T17:45:00')
peak  = Time('2014-09-24T17:50:00')
end   = Time('2014-09-24T17:52:00')

ax.axvline(start.datetime, color="grey", linestyle="--", linewidth=1, label="Start")
ax.axvline(peak.datetime,  color="red",  linestyle="--", linewidth=1.2, label="Peak")
ax.axvline(end.datetime,   color="blue", linestyle="--", linewidth=1, label="End")

ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
ax.xaxis.set_major_locator(mdates.MinuteLocator(interval=2))
ax.grid(True)

ax.legend(fontsize=12, loc='upper right')
ax.set_xlabel('Time HH:MM:SS', fontsize=12)
ax.set_yscale('log')

plt.show()

# %%
# --- DataFrame ---
df = goes_15.to_dataframe()
goes_15 = ts.TimeSeries(df, goes_15.meta, goes_15.units)

goes_flare = goes_15.truncate("2014-09-24 17:48:50", "2014-09-24 17:49:50")

# === Original Data ===
times = goes_flare.time.datetime
flux_a = goes_flare.quantity("xrsa").value   # 1-8 Å
flux_b = goes_flare.quantity("xrsb").value   # 0.5-4 Å

# === Derivatives ===
# convert datetime to seconds relative to t0
t_seconds = (times - times[0]).astype("timedelta64[s]").astype(float)

dflux_a = np.gradient(flux_a, t_seconds)  # d(flux)/dt
dflux_b = np.gradient(flux_b, t_seconds)
# Gradient in numpy uses: second-order accurate central difference

# === Plot ===
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8), sharex=True)

# Panel 1: Flux
ax1.set_title("2014-09-24 GOES X-ray fluxes and derivatives (C7.0 flare)")
ax1.plot(times, flux_b, 'x',label="1.0–8.0 Å", color="C1")
ax1.plot(times, flux_a,'x', label="0.5–4.0 Å", color="C0")
ax1.set_ylabel("Flux (W m$^{-2}$)")
ax1.set_yscale("log")
ax1.legend()
ax1.grid(True)

# Panel 2: Derivatives
ax2.step(times, dflux_b, where='mid', color="C1", label="d/dt (1–8 Å)")
ax2.step(times, dflux_a, where='mid', color="C0", label="d/dt (0.5–4 Å)")

ax2.axhline(0, color="k", linestyle="--", linewidth=0.8)
ax2.set_ylabel("Derivative (W m$^{-2}$ s$^{-1}$)")
ax2.legend()
ax2.grid(True)
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
ax2.xaxis.set_major_locator(mdates.MinuteLocator(interval=2))
ax2.set_xlabel("Time (HH:MM:SS)")

plt.tight_layout()
plt.show()
